# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/BilaalBakare/Flyrank-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
#
# I'm choosing this lane because my initial exploration already points toward signal-level questions rather than a single ranking task. I found that avg_position and ctr show almost no linear correlation (~-0.07) in my sample, which contradicts the simple assumption that "better position always means better CTR" and I saw a weak, counter-intuitive relationship between content_age_days and trend_direction, where older pages skew slightly toward stable/improving rather than declining. These early signals suggest there's real value in systematically testing which factors actually associate with search performance, rather than assuming the obvious ones (position, age) drive it which is exactly what this lane is built to investigate.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# Decision: Which ranking signals (position, CTR, content age, etc.) should the SEO/content team actually trust and prioritize when deciding where to focus effort instead of relying on assumptions like "high search volume = high traffic" or "older content = declining."
#
# Action: An SEO strategist or content lead uses the signal report to decide which factors are worth building future scoring/prioritization systems around (e.g., focusing on CTR-position mismatches rather than content age, if age turns out to be weak).
#
# Cost of a wrong call: If we wrongly flag a weak signal (like content age) as a strong driver of decline, the team could spend time refreshing old-but-healthy pages while ignoring the pages actually losing rank for other reasons — wasted effort, and real declining pages left unaddressed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")
df.sample(5)
# Out:
#                  content_id          client_id  search_volume  competition  \
# 17472  content_2ecaf151826f  client_9f14025af0            0.0         0.00
# 19194  content_1c3154cc7576  client_3fdba35f04           10.0         0.46
# 8738   content_da89e57b77d7  client_3fdba35f04           70.0         0.00
# 16320  content_130aa3eb5c66  client_19581e27de           40.0         0.06
# 5823   content_194a3cd73c28  client_624b60c58c            NaN          NaN
#
#       competition_level   cpc     content_type    main_intent  word_count  \
# 17472               LOW  0.00  keyword article  informational      2991.0
# 19194            MEDIUM  2.14  keyword article  informational      1509.0
# 8738                LOW  0.00  keyword article  informational      2881.0
# 16320               LOW  0.11  keyword article  informational         NaN
# 5823                NaN   NaN   feedly article            NaN      3944.0
#
# ...

# %%
corr_val = df['avg_position'].corr(df['ctr'])

print(f'With a correlation value of {corr_val}, It show there is little to no relation between avg_position and ctr\nThis challenges the notion that higher position should equal high ctr, the now generates the question. What determines high ctr')
# Out:
# With a correlation value of -0.07259029976832464, It show there is little to no relation between avg_position and ctr
# This challenges the notion that higher position should equal high ctr, the now generates the question. What determines high ctr

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
#
# What this analysis can say:
#
# These are observed, correlational patterns in the starter dataset e.g., position and CTR show almost no linear relationship here, and content age differs modestly across trend-direction groups.
# These findings are directional signals hints about which factors might matter, useful for guiding where the team investigates next.
# The results are decision-support, not decisions themselves — they tell a strategist where to look, not what will definitely work.
#
# What this analysis can never say:
#
# It cannot prove causation a weak or strong correlation doesn't tell us why a relationship exists, only that it appears in this sample.
# It cannot predict how Google's algorithm behaves I'm observing outcomes in this dataset, not modeling search engine logic.
# It cannot generalize beyond this dataset's time window, site, or sample patterns here may not hold for other sites, industries, or time periods.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ * ] Every section above is filled — markdown thinking AND the code that backs it
# - [ * ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ * ] No client names, URLs, or private queries anywhere
# - [ * ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
